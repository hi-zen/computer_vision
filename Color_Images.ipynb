# %% [markdown]
# Full notebook -- https://colab.research.google.com/drive/1xXEukNNMDqDYOQQhZ0I1Ucpf_eLswmWq#scrollTo=3ekaVjb2sI_T

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from IPython.display import Image
plt.rcParams['image.cmap'] = 'gray'

if 'google.colab' in str(get_ipython()):
    print("Downloading Code to Colab Environment")
    # !wget https://www.dropbox.com/sh/8mu8erfnvqk3dzu/AABWmDJkjv-TvECMPRKlufNYa?dl=1 -O module-code.zip -q --show-progress
    # !unzip -qq module-code.zip
else:
    pass
# Out:
# Downloading Code to Colab Environment
# module-code.zip     100%[===================>]  31.27M  15.1MB/s    in 2.1s
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
# replace SAVED.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# read the image 
logo = '/content/facebook_logo.jpg'
logo_img = cv2.imread(logo, cv2.IMREAD_COLOR)

# Print the size of the image,
print("Image size is ", logo_img.shape)
# Out:
# Image size is  (301, 800, 3)

# %%
# Display the image 
plt.figure(figsize = (10, 10))
plt.imshow(logo_img);

# %%
# Swap the read and blue color channel 
logo_img = logo_img[:, :, ::-1]

# Display the image 
plt.figure(figsize=(10, 10))
plt.imshow(logo_img);

# %%
# Read and display png image 
logo = '/content/Pytorch_logo.png'
logo_img = cv2.imread(logo, cv2.IMREAD_COLOR)

# Print the size of the image
print("Image size is ", logo_img.shape)

# Display the image.
plt.figure(figsize=(12, 12))
plt.imshow(logo_img);
# Out:
# Image size is  (205, 1025, 3)

# %%
# Read the image 
logo = 'Pytorch_logo.png'
logo_img = cv2.imread(logo, cv2.IMREAD_UNCHANGED)

# print the size of the image.
print(logo_img.shape)

# display the image
plt.figure(figsize=(12, 12))
plt.imshow(logo_img);
# Out:
# (205, 1025, 4)

# %%
# Swap the Red and blue color channels using : cv2.COLOR_BGRA2RGBA
logo_img = cv2.cvtColor(logo_img, cv2.COLOR_BGRA2RGBA)

# display the image,
plt.figure(figsize=(12, 12))
plt.imshow(logo_img);

# %%
# Split the image into the B,G,R components.
img_bgr = cv2.imread('Emerald_Lakes_New_Zealand.jpg', cv2.IMREAD_COLOR)
b, g, r = cv2.split(img_bgr)

# Show the channels.
plt.figure(figsize = [20, 10])
plt.subplot(141); plt.imshow(r); plt.title('Red Channel')
plt.subplot(142); plt.imshow(g); plt.title('Green Channel')
plt.subplot(143); plt.imshow(b); plt.title('Blue Channel')

# Merge the individual channels into a BGR image.
imgMerged = cv2.merge((r, g, b))

# Display the merged output.
plt.subplot(144)
plt.imshow(imgMerged)
plt.title('Merged Output');

# %%
# Split the image into the B, G , components
img_bgr = cv2.imread('/content/Emerald_Lakes_New_Zealand.jpg', cv2.IMREAD_COLOR)
b, g, r = cv2.split(img_bgr)

# show the channels.
plt.figure(figsize=[20, 10])
plt.subplot(141); plt.imshow(r); plt.title("Red channel")
plt.subplot(142); plt.imshow(g); plt.title("Green channel")
plt.subplot(143); plt.imshow(b); plt.title('Blue')
